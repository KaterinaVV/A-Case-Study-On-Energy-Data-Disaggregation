# %%
import pandas as pd

# %% [markdown]
# # oth-regensburg-1_1_2022

# %%
data_archieve = pd.read_csv("oth-regensburg-1_1_2022/oth-regensburg-1.csv")
print(data_archieve.shape)
data_archieve.head()
# Out:
# /Users/ken/opt/anaconda3/envs/nilmtk-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3221: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# (2293528, 27)
#                                      Id                          Name  \
# 0  43043308-a366-4af4-881c-6bae4a0a0dc3  smart-me 6011785 - Allgemein
# 1  aa680cb9-5092-4483-84fe-a5df826a55c4     smart-me 6011209 Batterie
# 2  2c6913bf-c807-4592-a148-a891b6174aae               Gesamtverbrauch
# 3  53ad1504-0a3d-4074-b848-c4eb46367bab  Virtueller Produktionszähler
# 4  e8755559-b3da-4a71-baa6-109fd1304248    smart-me 6011227 - Heizung
#
#                Serial      DeviceEnergyType             MeterSubType  \
# 0             6011785  MeterTypeElectricity                      NaN
# 1             6011209  MeterTypeElectricity                      NaN
# ...

# %%
data_archieve.Name.unique()
# Out:
# array(['smart-me 6011785 - Allgemein', 'smart-me 6011209 Batterie',
#        'Gesamtverbrauch', 'Virtueller Produktionszähler',
#        'smart-me 6011227 - Heizung', 'smart-me 6011505 - Wohnung 1',
#        'smart-me 6011754 - Wohnung 2', 'smart-me 6011232 - Wohnung 3',
#        'smart-me 6011231 - Wohnung 4', 'smart-me 6011210 - Wohnung 5',
#        'smart-me 6011243 - Wohnung 6', 'smart-me 6011242 - Wohnung 7',
#        'NewDevice'], dtype=object)

# %%
data_archieve.ValueDate.unique()
# Out:
# array(['01/03/2022 13:40:01', '01/03/2022 13:39:49',
#        '01/03/2022 13:39:58', ..., '01/31/2022 22:59:57',
#        '01/31/2022 23:00:20', '01/31/2022 23:00:21'], dtype=object)

# %%
data_archieve_1 = pd.read_csv("oth-regensburg-1_1_2022/oth-regensburg-1(1).csv")
print(data_archieve_1.shape)
data_archieve_1.head()
# Out:
# (11, 27)
#                                      Id                          Name  \
# 0  43043308-a366-4af4-881c-6bae4a0a0dc3  smart-me 6011785 - Allgemein
# 1  aa680cb9-5092-4483-84fe-a5df826a55c4     smart-me 6011209 Batterie
# 2  e8755559-b3da-4a71-baa6-109fd1304248    smart-me 6011227 - Heizung
# 3  a9dad66e-8a0b-457f-8cd8-644aeddee557  smart-me 6011505 - Wohnung 1
# 4  1731e782-145c-4317-8291-f875746fdcc8  smart-me 6011754 - Wohnung 2
#
#     Serial      DeviceEnergyType  MeterSubType  ActivePower  CounterReading  \
# 0  6011785  MeterTypeElectricity           NaN     0.134519     1501.285658
# 1  6011209  MeterTypeElectricity           NaN    -0.008650     -652.061632
# 2  6011227  MeterTypeElectricity           NaN     4.489816    22903.766731
# 3  6011505  MeterTypeElectricity           NaN     0.127648     2093.418476
# 4  6011754  MeterTypeElectricity           NaN     0.453983     3173.136103
#
# ...

# %%
data_archieve_2 = pd.read_csv("oth-regensburg-1_1_2022/oth-regensburg-1(2).csv")
print(data_archieve_2.shape)
data_archieve_2.head()
# Out:
# (11, 27)
#                                      Id                          Name  \
# 0  43043308-a366-4af4-881c-6bae4a0a0dc3  smart-me 6011785 - Allgemein
# 1  aa680cb9-5092-4483-84fe-a5df826a55c4     smart-me 6011209 Batterie
# 2  e8755559-b3da-4a71-baa6-109fd1304248    smart-me 6011227 - Heizung
# 3  a9dad66e-8a0b-457f-8cd8-644aeddee557  smart-me 6011505 - Wohnung 1
# 4  1731e782-145c-4317-8291-f875746fdcc8  smart-me 6011754 - Wohnung 2
#
#     Serial      DeviceEnergyType  MeterSubType  ActivePower  CounterReading  \
# 0  6011785  MeterTypeElectricity           NaN     0.137462     1501.285771
# 1  6011209  MeterTypeElectricity           NaN    -0.008650     -652.061632
# 2  6011227  MeterTypeElectricity           NaN     4.489316    22903.769226
# 3  6011505  MeterTypeElectricity           NaN     0.127595     2093.418547
# 4  6011754  MeterTypeElectricity           NaN     0.407368     3173.136468
#
# ...

# %% [markdown]
# # oth-regensburg-1

# %%
data = pd.read_csv("oth-regensburg-1/oth-regensburg-1.csv")
print(data.shape)
data.head()
# Out:
# (1550472, 27)
#                                      Id                          Name  \
# 0  43043308-a366-4af4-881c-6bae4a0a0dc3  smart-me 6011785 - Allgemein
# 1  aa680cb9-5092-4483-84fe-a5df826a55c4     smart-me 6011209 Batterie
# 2  2c6913bf-c807-4592-a148-a891b6174aae               Gesamtverbrauch
# 3  e8755559-b3da-4a71-baa6-109fd1304248    smart-me 6011227 - Heizung
# 4  a9dad66e-8a0b-457f-8cd8-644aeddee557  smart-me 6011505 - Wohnung 1
#
#                Serial      DeviceEnergyType             MeterSubType  \
# 0             6011785  MeterTypeElectricity                      NaN
# 1             6011209  MeterTypeElectricity                      NaN
# 2  637686123692284276                    13  MeterSubTypeElectricity
# 3             6011227  MeterTypeElectricity                      NaN
# 4             6011505  MeterTypeElectricity                      NaN
#
#    ActivePower  CounterReading  CounterReadingT1  CounterReadingT2  \
# ...

# %%
data.Name.unique()
# Out:
# array(['smart-me 6011785 - Allgemein', 'smart-me 6011209 Batterie',
#        'Gesamtverbrauch', 'smart-me 6011227 - Heizung',
#        'smart-me 6011505 - Wohnung 1', 'smart-me 6011754 - Wohnung 2',
#        'smart-me 6011232 - Wohnung 3', 'smart-me 6011231 - Wohnung 4',
#        'smart-me 6011210 - Wohnung 5', 'smart-me 6011243 - Wohnung 6',
#        'smart-me 6011242 - Wohnung 7', 'NewDevice'], dtype=object)

# %% [markdown]
# # Wohnung 1

# %%
data[data.Name.str.contains("Wohnung 1")].shape
# Out:
# (129206, 27)

# %%
data[data.Name.str.contains("Wohnung 1")].head()
# Out:
#                                       Id                          Name  \
# 4   a9dad66e-8a0b-457f-8cd8-644aeddee557  smart-me 6011505 - Wohnung 1
# 16  a9dad66e-8a0b-457f-8cd8-644aeddee557  smart-me 6011505 - Wohnung 1
# 28  a9dad66e-8a0b-457f-8cd8-644aeddee557  smart-me 6011505 - Wohnung 1
# 40  a9dad66e-8a0b-457f-8cd8-644aeddee557  smart-me 6011505 - Wohnung 1
# 52  a9dad66e-8a0b-457f-8cd8-644aeddee557  smart-me 6011505 - Wohnung 1
#
#      Serial      DeviceEnergyType MeterSubType  ActivePower  CounterReading  \
# 4   6011505  MeterTypeElectricity          NaN     0.052729     4050.142234
# 16  6011505  MeterTypeElectricity          NaN     0.053102     4050.142263
# 28  6011505  MeterTypeElectricity          NaN     0.052937     4050.142293
# 40  6011505  MeterTypeElectricity          NaN     0.052926     4050.142322
# 52  6011505  MeterTypeElectricity          NaN     0.053356     4050.142337
#
#     CounterReadingT1  CounterReadingT2  CounterReadingExport  ...  VoltageL3  \
# ...

# %%
wohnung_1 = pd.read_csv("Wohnung1.csv")
wohnung_1.head()
# Out:
#    Unnamed: 0  ActivePower                  ValueDate
# 0           0       52.729  2023-08-01 00:00:03+02:00
# 1           1       53.102  2023-08-01 00:00:05+02:00
# 2           2       52.937  2023-08-01 00:00:07+02:00
# 3           3       52.926  2023-08-01 00:00:09+02:00
# 4           4       53.356  2023-08-01 00:00:10+02:00

# %%
wohnung_1.shape
# Out:
# (4202, 11)
