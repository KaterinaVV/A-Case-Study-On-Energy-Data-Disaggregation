# %%
import nilmtk
from nilmtk import DataSet, TimeFrame, MeterGroup, HDFDataStore
from nilmtk.legacy.disaggregate import CombinatorialOptimisation
from nilmtk.utils import print_dict
from nilmtk.metrics import f1_score

# %%
data = DataSet('SmartMe.h5')
# Out:
# /Users/ken/opt/anaconda3/envs/nilmtk-env/lib/python3.8/site-packages/nilmtk/metergroup.py:85: RuntimeWarning: Building 1 has an empty 'appliances' list.
#   warnings.warn("Building {} has an empty 'appliances' list."
# /Users/ken/opt/anaconda3/envs/nilmtk-env/lib/python3.8/site-packages/nilmtk/metergroup.py:85: RuntimeWarning: Building 2 has an empty 'appliances' list.
#   warnings.warn("Building {} has an empty 'appliances' list."
# /Users/ken/opt/anaconda3/envs/nilmtk-env/lib/python3.8/site-packages/nilmtk/metergroup.py:85: RuntimeWarning: Building 3 has an empty 'appliances' list.
#   warnings.warn("Building {} has an empty 'appliances' list."
# /Users/ken/opt/anaconda3/envs/nilmtk-env/lib/python3.8/site-packages/nilmtk/metergroup.py:85: RuntimeWarning: Building 4 has an empty 'appliances' list.
#   warnings.warn("Building {} has an empty 'appliances' list."
# /Users/ken/opt/anaconda3/envs/nilmtk-env/lib/python3.8/site-packages/nilmtk/metergroup.py:85: RuntimeWarning: Building 5 has an empty 'appliances' list.
#   warnings.warn("Building {} has an empty 'appliances' list."
# /Users/ken/opt/anaconda3/envs/nilmtk-env/lib/python3.8/site-packages/nilmtk/metergroup.py:85: RuntimeWarning: Building 6 has an empty 'appliances' list.
#   warnings.warn("Building {} has an empty 'appliances' list."
# /Users/ken/opt/anaconda3/envs/nilmtk-env/lib/python3.8/site-packages/nilmtk/metergroup.py:85: RuntimeWarning: Building 7 has an empty 'appliances' list.
#   warnings.warn("Building {} has an empty 'appliances' list."

# %%
data.set_window(start='2023-08-01', end='2023-08-07')
elec_2 = data.buildings[2].elec
mains=elec_2.mains()
submeters=elec_2.submeters()
from nilmtk.legacy.disaggregate.hart_85 import Hart85
h = Hart85()
h.train(mains, columns=[('power', 'active')], noise_level=40)
output = HDFDataStore('output2.h5', 'w')
df2=h.disaggregate(mains, output)
df2
# Out:
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Next Chunk..
# Next Chunk..
# Next Chunk..
# Next Chunk..
# Next Chunk..
# Appending mains data to datastore
# Done
#                             0  1  2  3  4    5  6
# 2023-08-05 08:14:00+02:00   0  0  0  0  0    0  0
# 2023-08-05 08:15:00+02:00   0  0  0  0  0    0  0
# 2023-08-05 08:16:00+02:00   0  0  0  0  0    0  0
# 2023-08-05 08:17:00+02:00   0  0  0  0  0    0  0
# 2023-08-05 08:18:00+02:00   0  0  0  0  0    0  0
# ...                        .. .. .. .. ..  ... ..
# 2023-08-06 23:55:00+02:00   0  0  0  0  0  702  0
# 2023-08-06 23:56:00+02:00   0  0  0  0  0  702  0
# 2023-08-06 23:57:00+02:00   0  0  0  0  0  702  0
# 2023-08-06 23:58:00+02:00  81  0  0  0  0  702  0
# 2023-08-06 23:59:00+02:00   0  0  0  0  0    0  0
#
# [2386 rows x 7 columns]

# %%
elec_3 = data.buildings[3].elec
mains=elec_3.mains()
submeters=elec_3.submeters()
from nilmtk.legacy.disaggregate.hart_85 import Hart85
h = Hart85()
h.train(mains, columns=[('power', 'active')], noise_level=40)
output = HDFDataStore('output3.h5', 'w')
df3=h.disaggregate(mains, output)
df3
# Out:
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# /Users/ken/opt/anaconda3/envs/nilmtk-env/lib/python3.8/site-packages/nilmtk/utils.py:509: UserWarning: Found duplicate index. Keeping first value
#   warnings.warn("Found duplicate index. Keeping first value")
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Next Chunk..
# Next Chunk..
# Next Chunk..
# Next Chunk..
# Next Chunk..
# Appending mains data to datastore
# Done
#                            0  1  2  3
# 2023-08-05 08:14:00+02:00  0  0  0  0
# 2023-08-05 08:15:00+02:00  0  0  0  0
# 2023-08-05 08:16:00+02:00  0  0  0  0
# 2023-08-05 08:17:00+02:00  0  0  0  0
# 2023-08-05 08:18:00+02:00  0  0  0  0
# ...                       .. .. .. ..
# 2023-08-06 23:55:00+02:00  0  0  0  0
# 2023-08-06 23:56:00+02:00  0  0  0  0
# 2023-08-06 23:57:00+02:00  0  0  0  0
# 2023-08-06 23:58:00+02:00  0  0  0  0
# 2023-08-06 23:59:00+02:00  0  0  0  0
#
# [2386 rows x 4 columns]

# %%
elec_4 = data.buildings[4].elec
mains=elec_4.mains()
submeters=elec_4.submeters()
from nilmtk.legacy.disaggregate.hart_85 import Hart85
h = Hart85()
h.train(mains, columns=[('power', 'active')], noise_level=40)
output = HDFDataStore('output4.h5', 'w')
df4=h.disaggregate(mains, output)
df4
# Out:
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# /Users/ken/opt/anaconda3/envs/nilmtk-env/lib/python3.8/site-packages/nilmtk/utils.py:509: UserWarning: Found duplicate index. Keeping first value
#   warnings.warn("Found duplicate index. Keeping first value")
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Next Chunk..
# Next Chunk..
# Next Chunk..
# Next Chunk..
# Next Chunk..
# Next Chunk..
# Appending mains data to datastore
# Done
#                             0  1  2  3  4
# 2023-08-06 09:53:00+02:00   0  0  0  0  0
# 2023-08-06 09:54:00+02:00   0  0  0  0  0
# 2023-08-06 09:55:00+02:00   0  0  0  0  0
# 2023-08-06 09:56:00+02:00   0  0  0  0  0
# 2023-08-06 09:57:00+02:00  75  0  0  0  0
# ...                        .. .. .. .. ..
# 2023-08-06 23:55:00+02:00  75  0  0  0  0
# 2023-08-06 23:56:00+02:00  75  0  0  0  0
# 2023-08-06 23:57:00+02:00  75  0  0  0  0
# 2023-08-06 23:58:00+02:00  75  0  0  0  0
# 2023-08-06 23:59:00+02:00   0  0  0  0  0
#
# [847 rows x 5 columns]

# %%
elec_5 = data.buildings[5].elec
mains=elec_5.mains()
submeters=elec_5.submeters()
from nilmtk.legacy.disaggregate.hart_85 import Hart85
h = Hart85()
h.train(mains, columns=[('power', 'active')], noise_level=40)
output = HDFDataStore('output5.h5', 'w')
df5=h.disaggregate(mains, output)
df5
# Out:
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Next Chunk..
# Next Chunk..
# Next Chunk..
# Next Chunk..
# Next Chunk..
# Next Chunk..
# Appending mains data to datastore
# Done
#                            0  1  2  3  4
# 2023-08-06 09:53:00+02:00  0  0  0  0  0
# 2023-08-06 09:54:00+02:00  0  0  0  0  0
# 2023-08-06 09:55:00+02:00  0  0  0  0  0
# 2023-08-06 09:56:00+02:00  0  0  0  0  0
# 2023-08-06 09:57:00+02:00  0  0  0  0  0
# ...                       .. .. .. .. ..
# 2023-08-06 23:55:00+02:00  0  0  0  0  0
# 2023-08-06 23:56:00+02:00  0  0  0  0  0
# 2023-08-06 23:57:00+02:00  0  0  0  0  0
# 2023-08-06 23:58:00+02:00  0  0  0  0  0
# 2023-08-06 23:59:00+02:00  0  0  0  0  0
#
# [847 rows x 5 columns]

# %%
elec_6 = data.buildings[6].elec
mains=elec_6.mains()
submeters=elec_6.submeters()
from nilmtk.legacy.disaggregate.hart_85 import Hart85
h = Hart85()
h.train(mains, columns=[('power', 'active')], noise_level=40)
output = HDFDataStore('output6.h5', 'w')
df6=h.disaggregate(mains, output)
df6
# Out:
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# /Users/ken/opt/anaconda3/envs/nilmtk-env/lib/python3.8/site-packages/nilmtk/utils.py:509: UserWarning: Found duplicate index. Keeping first value
#   warnings.warn("Found duplicate index. Keeping first value")
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Next Chunk..
# Next Chunk..
# Next Chunk..
# Next Chunk..
# Next Chunk..
# Appending mains data to datastore
# Done
#                            0  1
# 2023-08-05 08:14:00+02:00  0  0
# 2023-08-05 08:15:00+02:00  0  0
# 2023-08-05 08:16:00+02:00  0  0
# 2023-08-05 08:17:00+02:00  0  0
# 2023-08-05 08:18:00+02:00  0  0
# ...                       .. ..
# 2023-08-06 23:55:00+02:00  0  0
# 2023-08-06 23:56:00+02:00  0  0
# 2023-08-06 23:57:00+02:00  0  0
# 2023-08-06 23:58:00+02:00  0  0
# 2023-08-06 23:59:00+02:00  0  0
#
# [2386 rows x 2 columns]

# %%
elec_7 = data.buildings[7].elec
mains=elec_7.mains()
submeters=elec_7.submeters()
from nilmtk.legacy.disaggregate.hart_85 import Hart85
h = Hart85()
h.train(mains, columns=[('power', 'active')], noise_level=40)
output = HDFDataStore('output7.h5', 'w')
df7=h.disaggregate(mains, output)
df7
# Out:
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Next Chunk..
# Next Chunk..
# Next Chunk..
# Next Chunk..
# Next Chunk..
# Appending mains data to datastore
# Done
#                             0  1  2  3  4  5  6  7
# 2023-08-05 08:14:00+02:00   0  0  0  0  0  0  0  0
# 2023-08-05 08:15:00+02:00   0  0  0  0  0  0  0  0
# 2023-08-05 08:16:00+02:00   0  0  0  0  0  0  0  0
# 2023-08-05 08:17:00+02:00  75  0  0  0  0  0  0  0
# 2023-08-05 08:18:00+02:00   0  0  0  0  0  0  0  0
# ...                        .. .. .. .. .. .. .. ..
# 2023-08-06 23:55:00+02:00   0  0  0  0  0  0  0  0
# 2023-08-06 23:56:00+02:00   0  0  0  0  0  0  0  0
# 2023-08-06 23:57:00+02:00   0  0  0  0  0  0  0  0
# 2023-08-06 23:58:00+02:00   0  0  0  0  0  0  0  0
# 2023-08-06 23:59:00+02:00   0  0  0  0  0  0  0  0
#
# [2386 rows x 8 columns]
